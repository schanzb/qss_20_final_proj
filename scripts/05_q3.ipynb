# %% [markdown]
# ## Question 3: Counter-Spending / Arms Race
# - Aggregate to **weekly time series** within each cycle
# - Compute **Arms Race Index** = min(pro_R, pro_D) / max(pro_R, pro_D) — 1.0 = perfect parity
# - Apply **Granger causality tests** to assess whether spending spikes by one party predict reactive spending by the other in subsequent weeks
# - Test hypothesis: massive IEs by one party trigger roughly equivalent counter-spending from the other (the strategic arms race)

# %%
# Load packages + connect to database
import sqlite3
import getpass
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from statsmodels.tsa.stattools import grangercausalitytests


# Close any existing connection from a previous run
try:
    conn.close()
except Exception:
    pass

_user = getpass.getuser()  # works on Windows, Linux, and macOS
_candidates = [
    '../data/citizens_united.db',                                                        # relative to script (works for any repo clone)
    os.path.expanduser('~/qss_20_final_proj/data/citizens_united.db'),                   # home dir, any OS
    f'/home/{_user}/qss_20_final_proj/data/citizens_united.db',                          # Linux / WSL home explicit
    rf'\\wsl.localhost\Ubuntu\home\{_user}\qss_20_final_proj\data\citizens_united.db',   # Windows → WSL Ubuntu UNC
]

def _make_uri(path):
    """Return a SQLite file URI for *path* (POSIX or Windows/UNC).
    Always resolves to an absolute path first so that relative paths
    that expand to UNC paths (e.g. on WSL) get the immutable=1 flag.
    """
    path = os.path.abspath(path)
    if path.startswith('\\\\'):
        # UNC path → file:////server/share/...?immutable=1
        # immutable=1 bypasses locking, which fails on WSL network paths
        uri_path = path.lstrip('\\').replace('\\', '/')
        return f'file:////{uri_path}?immutable=1'
    else:
        return f'file:{path}?mode=ro'

conn = None
for _path in _candidates:
    try:
        _uri = _make_uri(_path)
        conn = sqlite3.connect(_uri, uri=True)
        conn.execute('SELECT 1')
        print(f'Connected: {_path}')
        break
    except Exception:
        conn = None

if conn is None:
    raise FileNotFoundError('Database not found. Add your local path to _candidates above.')


# conn = sqlite3.connect('../data/citizens_united.db')


# output locations are ../figures and ../tables
# Out:
# Connected: ../data/citizens_united.db

# %% [markdown]
# ## 1. Load weekly partisan spending
#
# Query `partisan_spending_weekly` — the weekly-granularity version of the core derived table.
# Filter to `pro_R` and `pro_D` only. For each cycle, pivot into a DataFrame with columns `pro_R` and `pro_D`
# indexed by week. Missing weeks fill as 0.

# %%
# pull from DB
query = """
    SELECT Cycle, era, YearWeek, partisan_direction, spending_type,
           SUM(total_amount_2024) AS total
    FROM partisan_spending_weekly
    WHERE partisan_direction IN ('pro_R', 'pro_D')
    GROUP BY Cycle, era, YearWeek, partisan_direction, spending_type
    ORDER BY Cycle, YearWeek, partisan_direction
    """

df = pd.read_sql(query, conn)

# Aggregate across spending types; one total per (Cycle, YearWeek, partisan_direction)
weekly = (df.groupby(['Cycle', 'era', 'YearWeek', 'partisan_direction'], as_index=False)
            ['total'].sum())

# Pivot: rows = YearWeek, columns = pro_R / pro_D; fill missing weeks with 0
# Create a dictionary of datafames, one per cycle, with columns for pro_R and pro_D spending by week of election cycle
cycles_weekly = {}
for cycle, grp in weekly.groupby('Cycle'):
    pivot = (grp.pivot_table(index='YearWeek', columns='partisan_direction',
                             values='total', aggfunc='sum')
               .reindex(columns=['pro_R', 'pro_D'])
               .fillna(0)
               .sort_index()
               .reset_index())
    pivot['era'] = grp['era'].iloc[0]
    cycles_weekly[cycle] = pivot

# preview each cycle's dataframe
for cycle, df_c in cycles_weekly.items():
    print(f"Cycle {cycle}  ({df_c['era'].iloc[0]})  — {len(df_c)} weeks")
    print(df_c.head(3), "\n")
# Out:
# Cycle 2004  (pre_CU)  — 102 weeks
# partisan_direction YearWeek  pro_R       pro_D     era
# 0                   2000-12    0.0 -15875.3049  pre_CU
# 1                   2000-13    0.0  -8989.2894  pre_CU
# 2                   2002-12    0.0  -1332.2400  pre_CU
#
# Cycle 2008  (pre_CU)  — 103 weeks
# partisan_direction YearWeek   pro_R    pro_D     era
# 0                   2001-35  1461.1     0.00  pre_CU
# 1                   2005-25     0.0     0.00  pre_CU
# 2                   2005-42     0.0 -3652.75  pre_CU
#
# Cycle 2012  (post_CU)  — 107 weeks
# partisan_direction YearWeek      pro_R  pro_D      era
# 0                   2008-12  1658.6933    0.0  post_CU
# 1                   2010-37   680.3500    0.0  post_CU
# 2                   2010-40   340.1750    0.0  post_CU
#
# Cycle 2020  (post_CU)  — 212 weeks
# partisan_direction YearWeek     pro_R  pro_D      era
# 0                   2016-30  290.9760    0.0  post_CU
# 1                   2016-31  436.4640    0.0  post_CU
# ...

# %% [markdown]
# ## 2. Compute Arms Race Index per cycle
#
# Arms Race Index (ARI) = min(pro_R, pro_D) / max(pro_R, pro_D) for each week.
# - 1.0 = both sides spending identically (perfect arms race)
# - 0.0 = one side completely dominates
# - Undefined when both sides spend $0 → exclude from summary stats
#
# Also compute a **4-week rolling average** to smooth lumpy campaign spending patterns.
# Record mean and median ARI per cycle.

# %%
CYCLES      = sorted(cycles_weekly.keys()) # list of cycles in chronological order
ERA_LABELS  = {c: cycles_weekly[c]['era'].iloc[0].replace('_', '-') for c in CYCLES} # map cycle to era label (e.g., "Cycle 1" → "Pre-CU")

# init empty dictionaries to store ARI summary stats by cycle
mean_ari   = {}
median_ari = {}

for cycle in CYCLES: # for each cycle
    w         = cycles_weekly[cycle] # get the cycle's weekly data
    max_spend = w[['pro_R', 'pro_D']].max(axis=1) # get the max spend by week (denominator of ARI)
    min_spend = w[['pro_R', 'pro_D']].min(axis=1) # get the min spend by week (numerator of ARI)

    # ARI undefined when both sides spend $0 → NaN excluded from summary stats
    w['arms_race_index'] = min_spend / max_spend.replace(0, np.nan) # compute ARI by week; replace 0 denominator with NaN to avoid division by zero
    w['ari_rolling']     = w['arms_race_index'].rolling(4, min_periods=1).mean() # compute 4-week rolling average of ARI

    mean_ari[cycle]   = w['arms_race_index'].mean() # compute mean ARI for the cycle
    median_ari[cycle] = w['arms_race_index'].median() # compute median ARI for the cycle

ari_summary = pd.DataFrame({
    'era':        [ERA_LABELS[c]              for c in CYCLES], # map cycle to era label (e.g., "Cycle 1" → "Pre-CU")
    'mean_ARI':   [round(mean_ari[c],   3)    for c in CYCLES], # compute mean ARI for the cycle
    'median_ARI': [round(median_ari[c], 3)    for c in CYCLES],# compute median ARI for the cycle
    'n_weeks':    [len(cycles_weekly[c])       for c in CYCLES], # get number of weeks in the cycle's dataframe
}, index=CYCLES) # set cycle number as index
ari_summary.index.name = 'Cycle' # name the index "Cycle"
print(ari_summary) # print summary stats for ARI by cycle
# Out:
#            era  mean_ARI  median_ARI  n_weeks
# Cycle
# 2004    pre-CU     0.351       0.300      102
# 2008    pre-CU     0.643       0.728      103
# 2012   post-CU     0.598       0.648      107
# 2020   post-CU   -85.043       0.195      212

# %% [markdown]
# ## 3. Granger causality tests
#
# Test: does pro_R spending in week *t* predict pro_D spending in week *t+k* (and vice versa)?
#
# Use `statsmodels.tsa.stattools.grangercausalitytests` with `maxlag=4`.
# Extract F-test p-values for lags 1–4 in both directions (R→D and D→R).
#
# **Caveat:** Granger causality tests predictive precedence, not true causation.
# With ~90 weekly observations per cycle, the test has reasonable power at short lags.

# %%
MAX_LAG = 4 # max lag of 4 weeks (1 month) for Granger causality tests

p_RtoD = {c: {} for c in CYCLES} # init empty dictionary to store p-values for Granger causality tests of pro_R → pro_D by cycle and lag
p_DtoR = {c: {} for c in CYCLES} # init empty dictionary to store p-values for Granger causality tests of pro_D → pro_R by cycle and lag

for cycle in CYCLES: # for each cycle
    w  = cycles_weekly[cycle] # get the cycle's weekly data
    # clip negatives (refunds/corrections) to 0, then log1p to reduce skew
    ts = np.log1p(w[['pro_R', 'pro_D']].fillna(0).clip(lower=0)) # create a time series dataframe with log-transformed pro_R and pro_D spending by week; fill missing values with 0 and clip negatives to 0 before log-transforming

    try:
        res_RtoD = grangercausalitytests(ts[['pro_D', 'pro_R']], maxlag=MAX_LAG) # test whether pro_R Granger-causes pro_D
        res_DtoR = grangercausalitytests(ts[['pro_R', 'pro_D']], maxlag=MAX_LAG) # test whether pro_D Granger-causes pro_R
        for lag in range(1, MAX_LAG + 1): # for each lag, extract the p-value from the F-test of whether the lagged values of the "causing" variable improve model fit
            p_RtoD[cycle][lag] = res_RtoD[lag][0]['ssr_ftest'][1] # store p-value for pro_R → pro_D at this lag
            p_DtoR[cycle][lag] = res_DtoR[lag][0]['ssr_ftest'][1] # store p-value for pro_D → pro_R at this lag
    except Exception as e: # catch and print any errors
        print(f"Cycle {cycle}: {e}")

# Tidy DataFrames for heatmap — rows=cycle, cols=lag
granger_RtoD = pd.DataFrame(p_RtoD, index=range(1, MAX_LAG + 1)).T  # convert dictionary of p-values for pro_R → pro_D into a DataFrame with cycles as rows and lags as columns
granger_RtoD.index.name   = 'Cycle' # name the index "Cycle"
granger_RtoD.columns.name = 'Lag' # name the columns "Lag"

granger_DtoR = pd.DataFrame(p_DtoR, index=range(1, MAX_LAG + 1)).T # convert dictionary of p-values for pro_D → pro_R into a DataFrame with cycles as rows and lags as columns
granger_DtoR.index.name   = 'Cycle' # name the index "Cycle"
granger_DtoR.columns.name = 'Lag' # name the columns "Lag"
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2209  , p=0.6394  , df_denom=98, df_num=1
# ssr based chi2 test:   chi2=0.2277  , p=0.6333  , df=1
# likelihood ratio test: chi2=0.2274  , p=0.6335  , df=1
# parameter F test:         F=0.2209  , p=0.6394  , df_denom=98, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1702  , p=0.1198  , df_denom=95, df_num=2
# ssr based chi2 test:   chi2=4.5689  , p=0.1018  , df=2
# likelihood ratio test: chi2=4.4676  , p=0.1071  , df=2
# parameter F test:         F=2.1702  , p=0.1198  , df_denom=95, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1227  , p=0.3441  , df_denom=92, df_num=3
# ssr based chi2 test:   chi2=3.6243  , p=0.3050  , df=3
# likelihood ratio test: chi2=3.5595  , p=0.3131  , df=3
# parameter F test:         F=1.1227  , p=0.3441  , df_denom=92, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# ## 4. Print Granger summary
#
# Print a formatted table of p-values for both directions across all cycles and lags.
# Flag significant results (α=0.05 and α=0.10) with asterisks.

# %%
def sig_stars(p): # helper function to convert p-values to significance stars for display
    if p < 0.01: return '***' # three stars for p<0.01
    if p < 0.05: return '**' # two stars for p<0.05
    if p < 0.10: return '*' # one star for p<0.10
    return ''

header = f"{'Cycle':<6}  {'Direction':<8}" + ''.join(f"  Lag {l}" for l in range(1, MAX_LAG + 1)) # create a header for the results table with columns for cycle, direction, and each lag
print(header) # print the header for the results table
print('-' * len(header))

for cycle in CYCLES: # for each cycle
    for label, pdict in [('R→D', p_RtoD), ('D→R', p_DtoR)]: # for each direction of causality
        row = f"{cycle:<6}  {label:<8}" # start the row with the cycle number and direction label
        for lag in range(1, MAX_LAG + 1): # for each lag, get the p-value from the appropriate dictionary and add it to the row with significance stars
            p   = pdict[cycle].get(lag, float('nan')) # get the p-value for this cycle and lag; use NaN if not available
            row += f"  {p:.3f}{sig_stars(p):<2}" # append the p-value and significance stars to the row
        print(row)
    print()

print("*** p<0.01; ** p<0.05; * p<0.10")
# Out:
# Cycle   Direction  Lag 1  Lag 2  Lag 3  Lag 4
# ---------------------------------------------
# 2004    R→D       0.639    0.120    0.344    0.450
# 2004    D→R       0.000***  0.000***  0.000***  0.000***
#
# 2008    R→D       0.468    0.382    0.711    0.785
# 2008    D→R       0.000***  0.000***  0.004***  0.062*
#
# 2012    R→D       0.551    0.463    0.493    0.571
# 2012    D→R       0.030**  0.398    0.561    0.327
#
# 2020    R→D       0.010***  0.003***  0.008***  0.045**
# 2020    D→R       0.000***  0.000***  0.001***  0.002***
#
# *** p<0.01; ** p<0.05; * p<0.10

# %% [markdown]
# ## 5. Figure 1 — Weekly pro-R vs. pro-D time series (2×2 grid)
#
# One panel per cycle. Red line = pro-Republican weekly spending, blue line = pro-Democratic.
# Fill the gap between lines: red-shaded where Republican leads, blue-shaded where Democratic leads.
# X-axis: weeks since cycle start (Jan of odd year); Y-axis: 2024 $M.
# Include OpenSecrets attribution.

# %%
SOURCE = 'Source: Center for Responsive Politics, OpenSecrets.org' # source note for figures and tables

fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharey=False, constrained_layout=True) # create a 2x2 grid of subplots for the 4 cycles, with shared y-axis and constrained layout

for ax, cycle in zip(axes.flat, CYCLES): # for each subplot and cycle, plot the weekly pro_R and pro_D spending over time with shaded areas between them
    w   = cycles_weekly[cycle] # get the cycle's weekly data
    wks = range(len(w)) # get the week numbers (0-indexed) for the x-axis
    r   = w['pro_R'] / 1e6 # get pro_R spending in millions of 2024 dollars for the y-axis
    d   = w['pro_D'] / 1e6 # get pro_D spending in millions of 2024 dollars for the y-axis

    ax.plot(wks, r, color='#C0392B', lw=1.5, label='Pro-Republican') # plot pro_R spending over time in red
    ax.plot(wks, d, color='#2980B9', lw=1.5, label='Pro-Democratic') # plot pro_D spending over time in blue
    ax.fill_between(wks, r, d, where=(r >= d), alpha=0.15, color='#C0392B') # shade area between the lines in red where pro_R spending is greater than or equal to pro_D spending
    ax.fill_between(wks, r, d, where=(d >  r), alpha=0.15, color='#2980B9') # shade area between the lines in blue where pro_D spending is greater than pro_R spending

    ax.set_title(f"{cycle}  ({ERA_LABELS[cycle]})", fontsize=11) # set the title of the subplot to the cycle number and era label (e.g., "Cycle 1  (Pre-CU)")
    ax.set_xlabel('Week of cycle') # set the x-axis label to "Week of cycle"
    ax.set_ylabel('Weekly spending (2024 $M)') # set the y-axis label to "Weekly spending (2024 $M)"
    ax.legend(fontsize=8) # add a legend to the subplot with a smaller font size

fig.suptitle('Weekly Pro-R vs. Pro-D Presidential Spending by Cycle', fontsize=13) # set the overall title of the figure to "Weekly Pro-R vs. Pro-D Presidential Spending by Cycle"
fig.text(0.5, -0.01, SOURCE, ha='center', fontsize=8, color='gray') # add a source note below the figure with the text from the SOURCE variable, centered, in a smaller font size and gray color
plt.savefig('../figures/q3_fig1_weekly_timeseries.pdf', dpi=150, bbox_inches='tight') # save the figure as a PDF in the ../figures directory with a descriptive filename, 150 dpi resolution, and tight bounding box
plt.show()

# %% [markdown]
# ## 6. Figure 2 — Arms Race Index over time (2×2 grid)
#
# One panel per cycle showing the 4-week rolling ARI. Y-axis: 0 to 1.
# Horizontal dashed lines at 0.5 and 0.8 (parity thresholds).
# Green fill when ARI > 0.8 (strong arms race weeks).
# Panel title includes cycle mean ARI for quick comparison.
# Include OpenSecrets attribution.

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharey=True, constrained_layout=True) # create a 2x2 grid of subplots for the 4 cycles, with shared y-axis and constrained layout

for ax, cycle in zip(axes.flat, CYCLES): # for each subplot and cycle, plot the 4-week rolling average
    w    = cycles_weekly[cycle] # get the cycle's weekly data
    wks  = range(len(w)) # get the week numbers (0-indexed) for the x-axis
    roll = w['ari_rolling'] # get the 4-week rolling average of the ARI for the y-axis

    ax.plot(wks, roll, color='#2C3E50', lw=1.5, label='4-wk rolling ARI') # plot the 4-week rolling average of the ARI over time in dark gray
    ax.fill_between(wks, roll, 0.8,
                    where=(roll >= 0.8), alpha=0.25, color='#27AE60', label='ARI > 0.8') # shade area between the ARI line and the 0.8 threshold in green where the ARI is greater than or equal to 0.8
    ax.axhline(0.8, color='#27AE60', linestyle='--', lw=0.9, label='0.8 threshold') # add a horizontal dashed line at the 0.8 threshold in green
    ax.axhline(0.5, color='gray',    linestyle=':',  lw=0.8, label='0.5 threshold') # add a horizontal dotted line at the 0.5 threshold in gray
    ax.set_ylim(0, 1.05) # set the y-axis limits to 0 and 1.05 to give some space above the maximum ARI value of 1

    ax.set_title(f"{cycle}  ({ERA_LABELS[cycle]})  mean ARI={mean_ari[cycle]:.2f}", fontsize=11) # set the title of the subplot to the cycle number, era label, and mean ARI value (e.g., "Cycle 1  (Pre-CU)  mean ARI=0.45")
    ax.set_xlabel('Week of cycle') # set the x-axis label to "Week of cycle"
    ax.set_ylabel('Arms Race Index') # set the y
    ax.legend(fontsize=8) # add a legend to the subplot with a smaller font size

fig.suptitle('Arms Race Index (4-wk rolling avg) by Presidential Cycle', fontsize=13) # set the overall title of the figure
fig.text(0.5, -0.01, SOURCE, ha='center', fontsize=8, color='gray') # add a source note below the figure with the text from the SOURCE variable, centered, in a smaller font size and gray color
plt.savefig('../figures/q3_fig2_arms_race_index.pdf', dpi=150, bbox_inches='tight') # save the figure as a PDF in the ../figures directory with a descriptive filename, 150 dpi resolution, and tight bounding box
plt.show()

# %% [markdown]
# ## 7. Figure 3 — Granger causality heatmap
#
# Two-panel heatmap (R→D and D→R). Rows = cycles, columns = lags 1–4.
# Color scale: dark = low p-value (significant), light = high p-value.
# Annotate each cell with exact p-value.
# This is the main statistical figure for Q3.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 4), constrained_layout=True) # create a 1x2 grid of subplots for the Granger causality heatmaps, with constrained layout

sns.heatmap(granger_RtoD.round(3), annot=True, fmt='.3f', 
            vmin=0, vmax=0.1, cmap='RdYlGn_r', linewidths=0.5, ax=ax1) # plot heatmap of p-values for pro_R → pro_D Granger causality tests, with annotations, a color range from 0 to 0.1, a red-yellow-green colormap reversed (so lower p-values are greener), and thin lines between cells
ax1.set_title('Pro-R spending → Pro-D response\n(F-test p-value; lower = more significant)',
              fontsize=10) # set the title of the first subplot to "Pro-R spending → Pro-D response" with a subtitle about the F-test p-values and significance
ax1.set_xlabel('Lag (weeks)') # set the x-axis label of the first subplot to "Lag (weeks)"

sns.heatmap(granger_DtoR.round(3), annot=True, fmt='.3f',
            vmin=0, vmax=0.1, cmap='RdYlGn_r', linewidths=0.5, ax=ax2) # plot heatmap of p-values for pro_D → pro_R Granger causality tests, with annotations, a color range from 0 to 0.1, a red-yellow-green colormap reversed (so lower p-values are greener), and thin lines between cells
ax2.set_title('Pro-D spending → Pro-R response\n(F-test p-value; lower = more significant)',
              fontsize=10) # set the title of the second subplot to "Pro-D spending → Pro-R response" with a subtitle about the F-test p-values and significance
ax2.set_xlabel('Lag (weeks)') # set the x-axis label of the second subplot to "Lag (weeks)"

fig.suptitle('Granger Causality Tests: Counter-Spending by Lag and Cycle', fontsize=12) # set the overall title of the figure to "Granger Causality Tests: Counter-Spending by Lag and Cycle"
fig.text(0.5, -0.01, SOURCE, ha='center', fontsize=8, color='gray') # add a source note below the figure with the text from the SOURCE variable, centered, in a smaller font size and gray color
plt.savefig('../figures/q3_fig3_granger_heatmap.pdf', dpi=150, bbox_inches='tight') # save the figure as a PDF in the ../figures directory with a descriptive filename, 150 dpi resolution, and tight bounding box
plt.show()

# %% [markdown]
# ## 8. Save results tables
#
# - `../tables/q3_granger_results.csv` — p-values for both directions, all cycles and lags
# - `../tables/q3_arms_race_index.csv` — mean/median ARI per cycle
# - `../tables/q3_weekly_spending.csv` — full weekly pro_R / pro_D data (all cycles)

# %%
# Granger results — tidy format (both directions)
granger_tidy = pd.concat([
    granger_RtoD.stack().rename('p_value').reset_index().assign(direction='R→D'),
    granger_DtoR.stack().rename('p_value').reset_index().assign(direction='D→R'),
], ignore_index=True) # convert the wide-format Granger causality results DataFrames into a tidy format with columns for cycle, lag, p-value, and direction of causality
granger_tidy.to_csv('../tables/q3_granger_results.csv', index=False) # save the tidy Granger causality results to a CSV file in the ../tables directory with a descriptive filename and no index

# ARI summary — one row per cycle
ari_summary.reset_index().to_csv('../tables/q3_arms_race_index.csv', index=False) # save the ARI summary statistics (mean and median ARI by cycle) to a CSV file in the ../tables directory with a descriptive filename and no index

# Weekly spending — all cycles combined
weekly_all = pd.concat(
    [cycles_weekly[c].assign(Cycle=c) for c in CYCLES],
    ignore_index=True
) # combine the weekly spending data for all cycles into a single DataFrame with an additional column for the cycle number, and reset the index
weekly_all.to_csv('../tables/q3_weekly_spending.csv', index=False) # save the combined weekly spending data to a CSV file in the ../tables directory with a descriptive filename and no index

print("Saved:")
for f in ['q3_granger_results.csv', 'q3_arms_race_index.csv', 'q3_weekly_spending.csv']:
    print(f"  ../tables/{f}")
# Out:
# Saved:
#   ../tables/q3_granger_results.csv
#   ../tables/q3_arms_race_index.csv
#   ../tables/q3_weekly_spending.csv
